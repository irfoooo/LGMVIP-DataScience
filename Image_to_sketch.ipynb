# %% [markdown]
# <a href="https://colab.research.google.com/github/irfoooo/LGMVIP-DataScience/blob/main/Image_to_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMAGE TO PENCIL SKETCH USING PYTHON** by Mohammed Irfan S

# %% [markdown]
# **TASK-2** Convert a image to a pencil sketch

# %%
import numpy as np
import pandas as pd

import cv2 as cv
from google.colab.patches import cv2_imshow #image display
from skimage import io
from PIL import Image
import matplotlib.pyplot as plt
import urllib.request

# %%
image= io.imread("/content/trisha.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=602x742 at 0x7F8271DEB6D0>

# %%
grey_filter=cv.cvtColor(image,cv.COLOR_BGR2GRAY)
cv2_imshow(grey_filter)
# Out:
# <PIL.Image.Image image mode=L size=602x742 at 0x7F826FD16050>

# %%
invert=cv.bitwise_not(grey_filter)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=602x742 at 0x7F826FD167D0>

# %%
blur=cv.GaussianBlur(invert,(21,21),0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=602x742 at 0x7F826FD16550>

# %%
invertedblur=cv.bitwise_not(blur)
cv2_imshow(invertedblur)
# Out:
# <PIL.Image.Image image mode=L size=602x742 at 0x7F826FD16A10>

# %%
sketch_filter=cv.divide(grey_filter,invertedblur,scale=255.0)
cv2_imshow(sketch_filter)
cv.imwrite("sketch.jpg",sketch_filter)
# Out:
# <PIL.Image.Image image mode=L size=602x742 at 0x7F826FD1D750>
# True
